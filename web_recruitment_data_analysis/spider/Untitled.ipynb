# %%
# -*- coding:utf-8 -*-
import requests
from bs4 import BeautifulSoup

# %%
def get_html_page(lst,html):
    #print('running get_html_page')
    res = requests.get(html)
    res.encoding = 'utf-8'
    soup = BeautifulSoup(res.text, 'html.parser')
    #print(soup)
    for job in soup.select('.tHjob'):
        position = job.select('h1')[0]['title']
        print(position)
        lst.append(position)
        location = job.select('.lname')[0].text
        lst.append(location)
        salary = job.select('strong')[0].text
        lst.append(salary)
        companyname = job.select('a')[0]['title']
        if len(companyname)>0:
            lst.append(companyname)
        property = job.select('.ltype')[0].text
        lst.append(property)
        #print(len(lst))

    return lst

# %%
def write_txt(content):
    #print('running write_txt')
    with open('/Users/rogue_lee/Gitee/web_data_analysis/spider/mis-info.txt','a') as f:
        for item in content:
            f.write(item)

# %%
def main():
    print('running main')
    lst = []
    for url in open('/Users/rogue_lee/Gitee/web_data_analysis/spider/web-mis-url.txt'):
        print(url)
        content = get_html_page(lst, url)
        write_txt(content)
    print('Finished!')

# %%
main()
# Out:
# running main
# http://jobs.51job.com/shanghai-xhq/96253746.html?s=01&t=0
#
# Android mobile app����ʦ
# http://jobs.51job.com/wuhan-hsq/71614728.html?s=01&t=0
#
# .net������������ʦ����н+��Ч+��ĩ˫��+���գ�
# http://jobs.51job.com/jinan/92989482.html?s=01&t=0
#
# .NET��������ʦ
# http://jobs.51job.com/shenzhen/96274976.html?s=01&t=0
#
# Ƕ��ʽ������������ʦ
# http://jobs.51job.com/hefei-gxq/94895175.html?s=01&t=0
#
# NET������������ʦ
# http://jobs.51job.com/hefei/90883593.html?s=01&t=0
#
# php����ʦ
# http://jobs.51job.com/shanghai/96280420.html?s=01&t=0
#
# ������������ʦ��2018У�У�
# http://jobs.51job.com/beijing-hdq/96280164.html?s=01&t=0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-263240bbee7e> in <module>()
# ----> 1 main()
#
# <ipython-input-6-591d538ea79a> in main()
#       4     for url in open('/Users/rogue_lee/Gitee/web_data_analysis/spider/web-mis-url.txt'):
#       5         print(url)
# ----> 6         content = get_html_page(lst, url)
#       7         write_txt(content)
#       8     print('Finished!')
#
# <ipython-input-2-6bdf463bef14> in get_html_page(lst, html)
#       3     res = requests.get(html)
#       4     res.encoding = 'utf-8'
# ----> 5     soup = BeautifulSoup(res.text, 'html.parser')
#       6     #print(soup)
#       7     for job in soup.select('.tHjob'):
#
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# /usr/local/lib/python3.6/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     213         parser.soup = self.soup
#     214         try:
# --> 215             parser.feed(markup)
#     216         except HTMLParseError as e:
#     217             warnings.warn(RuntimeWarning(
#
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/html/parser.py in parse_starttag(self, i)
#     343             self.handle_startendtag(tag, attrs)
#     344         else:
# --> 345             self.handle_starttag(tag, attrs)
#     346             if tag in self.CDATA_CONTENT_ELEMENTS:
#     347                 self.set_cdata_mode(tag)
#
# /usr/local/lib/python3.6/site-packages/bs4/builder/_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#      88             attrvalue = '""'
#      89         #print "START", name
# ---> 90         tag = self.soup.handle_starttag(name, None, None, attr_dict)
#      91         if tag and tag.is_empty_element and handle_empty_element:
#      92             # Unlike other parsers, html.parser doesn't send separate end tag
#
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs)
#     463
#     464         tag = Tag(self, self.builder, name, namespace, nsprefix, attrs,
# --> 465                   self.currentTag, self._most_recent_element)
#     466         if tag is None:
#     467             return tag
#
# /usr/local/lib/python3.6/site-packages/bs4/element.py in __init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml)
#     840             if builder is not None and builder.cdata_list_attributes:
#     841                 attrs = builder._replace_cdata_list_attribute_values(
# --> 842                     self.name, attrs)
#     843             else:
#     844                 attrs = dict(attrs)
#
# /usr/local/lib/python3.6/site-packages/bs4/builder/__init__.py in _replace_cdata_list_attribute_values(self, tag_name, attrs)
#     168                     value = attrs[attr]
#     169                     if isinstance(value, str):
# --> 170                         values = whitespace_re.split(value)
#     171                     else:
#     172                         # html5lib sometimes calls setAttributes twice
#
# KeyboardInterrupt:
